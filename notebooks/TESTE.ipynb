# %%
import sys
print()
from pathlib import Path
sys.path.insert(0, str(Path("../src")))

from luna_data import load_candidates, CtScan, LunaDataset

candidates = load_candidates()
print(f"Candidatos: {len(candidates)}")
print(f"Nodulos: {sum(1 for c in candidates if c.is_nodule)}")
# Out:
# Candidatos: 551065
# Nodulos: 1351
